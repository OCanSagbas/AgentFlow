# %%
import os
import sys
import django

# Async güvensiz modunu etkinleştir
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Django projesinin path'ini ekle
sys.path.append('/home/ocans/DJANGO-AI-AGENT/src')

# Django settings'i tanımla
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'cfehome.settings')

# Django'yu başlat
django.setup()

# %%
from AI.llms import get_gemini_model

# %%
model = get_gemini_model()
model
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash', temperature=1.0, max_retries=2, client=<google.genai.client.Client object at 0x7a9578db37a0>, default_metadata=(), model_kwargs={})

# %%
model.invoke("Who are you?")
# Out:
# AIMessage(content="I am a large language model, an AI trained by Google.\n\nI don't have a name, personal feelings, consciousness, or a physical body. My purpose is to provide information, answer your questions, and assist you with a wide range of tasks by generating human-like text.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c2a81-f2c5-78a2-a0f8-50058eadd883-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5, 'output_tokens': 516, 'total_tokens': 521, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 457}})
