# %%
import os
import sys
import django

# Async güvensiz modunu etkinleştir
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Django projesinin path'ini ekle
sys.path.append('/home/ocans/DJANGO-AI-AGENT/src')

# Django settings'i tanımla
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'cfehome.settings')

# Django'yu başlat
django.setup()

# %%
from AI.supervisors import get_supervisor

# %%
from langgraph.checkpoint.memory import InMemorySaver

checkpointer = InMemorySaver()

# %%
supervisor = get_supervisor(model="gemini-2.5-flash", checkpointer=checkpointer)

# %%
import uuid
config = {"configurable": {"user_id": 2, "thread_id": uuid.uuid4()}}
response = supervisor.invoke(
    {"messages": 
        [
            {"role": "user", "content": "What are my recent documents?"}
        ]
    },
    config
)

# %%
response['messages'][-1].content
# Out:
# 'I can\'t filter by "recent" documents, but I can list all your documents:\n* ID: 3, Title: ""\n* ID: 2, Title: "Test Document"\n* ID: 1, Title: "Test Document"'

# %%
# Run the agent
response = agent.invoke(
    {"messages": 
        [
            {"role": "user", "content": "Are these duplicates?"}
        ]
    },
    config
)
response['messages'][-1].content
# Out:
# [{'type': 'text',
#   'text': "I can see that some of your documents have the same title, but I can't tell if they are duplicates because I don't have access to the document's content.",
#   'extras': {'signature': '...'}}]
